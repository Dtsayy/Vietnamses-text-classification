# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/TTTN/data_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                           Sentence  \
# 0           0  sở gd đt đề thi học_kỳ lớp xét tốt_nghiệp thcs...
# 1           1  ngày_công_bố danh_sách trường thpt công_lập tự...
# 2           2  quỹ tín_dụng sinh_viên nlđ ts lê bảo lâm hiệu_...
# 3           3  giảng_dạy đại_học trình_độ giáo_dục đại_học ta...
# 4           4  kẹt xe_kéo điểm_nóng cảnh kẹt xe_kéo_dài đường...
#
#   category_sentence
# 0  Chinh tri Xa hoi
# 1  Chinh tri Xa hoi
# 2  Chinh tri Xa hoi
# 3  Chinh tri Xa hoi
# 4  Chinh tri Xa hoi

# %%
X_data = df['Sentence']
y_data = df['category_sentence']

# %%
a=0
b=0 
c=0 
d=0 
e=0 
f=0 
g=0 
h=0 
j=0 
k=0 
for i in df['category_sentence']:
  if i in 'Chinh tri Xa hoi':
    a+=1
  elif i in 'Doi song':
    b+=1 
  elif i in 'Kinh doanh':
    c+=1
  elif i in 'Khoa hoc':
    d+=1
  elif i in 'Phap luat':
    e+=1
  elif i in 'Suc khoe':
    f+=1
  elif i in 'The gioi':
    g+=1
  elif i in 'The thao':
    h+=1
  elif i in 'Van hoa':
    j+=1
  elif i in 'Vi tinh':
    k+=1

# %%
x = ['CTXH','The gioi', 'The thao','Van hoa','Suc khoe','Kinh doanh','Vi tinh','Phap luat', 'Khoa hoc',  'Doi song']
y = [a, g, h, j, f, c, k, e, d, b]

# %%
print(i)
# Out:
# The gioi

# %%
fig = plt.figure(figsize=(7.20, 3.60))
plt.bar(x, y)
plt.xticks(rotation=30)
#plt.title('Chiều dài các bài báo')
plt.ylabel('số lượng câu')
plt.xlabel('Thể loại báo')
#plt.legend(['train', 'val'], loc='upper right')
plt.show()

# %%
len(data[2])
# Out:
# 403

# %%
amount = []
for i in data:
  amount.append(len(i))

# %%
c = []
for i in amount:
  if i < 5000:
    c.append(i)

# %%
max(amount)
# Out:
# 34746

# %%
plt.hist(c, bins=8, align='left');

# %%
a = []
for i in data[:10]:
  a.append(len(data))
  print(i)
# Out:
# sở gd đt đề thi học_kỳ lớp xét tốt_nghiệp thcs năm_học báo lao_động nêu sở gd đt tphcm giao phòng giáo_dục đề thi học_kỳ lớp phụ_huynh giáo_viên thắc_mắc địa_phương tp thơ sở đề kỳ thi học_kỳ lớp tp thơ sở gd đt tp đề giao huyện_thị đề nguyễn quý đôn phó_giám_đốc sở gđ đt tp thơ sở đề thi mặt_bằng chất_lượng địa_bàn tp giáo_viên trường dạy luyện thi tham_gia đề thi trường thpt địa_bàn tp đón_nhận tổng_số học_sinh lớp tham_gia xét tuyển thi_tuyển lớp trường thpt công_lập đón_nhận học_sinh số_lượng học_sinh học trường thpt bán_công dân_lập học_sinh tham_gia thi_tuyển lớp công_lập thi môn văn toán ngoại_ngữ học_sinh tham_gia xét tuyển trường bán_công_dân_lập dân_tộc nội_trú căn_cứ kết_quả học_tập hạnh_kiểm năm_học tiền giang lập ngân_hàng đề thi quách minh cường chuyên_viên phụ_trách thí vụ sở gd đt tiền giang sở đề thi học_kỳ khối lớp môn toán văn_học vật_lý sinh_vật lịch_sử địa_lý ngoại_ngữ giáo_dục công_dân hóa học cường sở đề thi môn đầu năm_học ban giám_đốc chỉ_đạo thi tốt_nghiệp t
# ...

# %%
a[2]
# Out:
# 50373

# %%
plt.hist(a)
# Out:
# (array([    0.,     0.,     0.,     0.,     0., 50373.,     0.,     0.,
#             0.,     0.]),
#  array([50372.5, 50372.6, 50372.7, 50372.8, 50372.9, 50373. , 50373.1,
#         50373.2, 50373.3, 50373.4, 50373.5]),
#  <a list of 10 Patch objects>)

# %%
d_f = pd.DataFrame({'x': data}, index = label)

# %%
#install pyvi package
# !pip install pyvi
# Out:
# ...
#      |████████████████████████████████| 8.5 MB 8.6 MB/s
# ...
#      |████████████████████████████████| 743 kB 45.2 MB/s
# ...

# %%
from pyvi import ViTokenizer, ViPosTagger # thư viện NLP tiếng Việt
from tqdm import tqdm
import numpy as np
import gensim # thư viện NLP

# %%
import os 

def get_data(folder_path):
    data = []
    labels = []
    dirs = os.listdir(folder_path)
    for path in tqdm(dirs):
        file_paths = os.listdir(os.path.join(folder_path, path))
        for file_path in (file_paths):
            with open(os.path.join(folder_path, path, file_path), 'r', encoding="utf-16") as f:
                lines = f.readlines()
                lines = ' '.join(lines)
                
#               Tien xu li du lieu don gian
                lines = gensim.utils.simple_preprocess(lines)
                lines = ' '.join(lines)
        
#               Tách từ tiếng Việt
                lines = ViTokenizer.tokenize(lines)
                data.append(lines)
                labels.append(path)

    return data, labels

# %%
X_data, y_data = get_data('/content/drive/MyDrive/TTTN/Train_Full')
# Out:
# 100%|██████████| 10/10 [06:21<00:00, 38.13s/it]

# %%
y_data[1]
# Out:
# 'Vi tinh'

# %%
len(y_data)
# Out:
# 33759

# %%
X_data[1]
# Out:
# 'sandisk sansa tuyên_chiến với ipod sansa dap digital audio player là dòng máy nghe nhạc kĩ_thuật_số đầu_tiên của sandisk khả_dĩ có_thể cạnh_tranh với ipods máy có kiểu_dáng nhỏ gọn rất xinh_xắn với màn_hình màu tft inches đĩa_cứng tùy theo loại sản_phẩm và giá_cả máy hỗ_trợ rất nhiều loại file âm_thanh và hình_ảnh thông_dụng hiện có kích_thước cm điểm đặc_biệt đầu_tiên sansa có hệ_thống pin rất linh_hoạt bạn có_thể thay_thế và tháo lắp dễ_dàng rất phù_hợp với các chuyến đi dài ngày và đương_nhiên cũng tùy túi_tiền mà bạn có_thể thay_thế các loại pin với trữ_lượng lớn hơn về giá_cả nếu so với ipod nano thì không có gì đặc_biệt tuy_nhiên sandisk đưa ra nhiều lựa_chọn hơn cho khách_hàng khi đưa ra các dòng sản_phẩm khác nhau với đĩa_cứng là gb máy sẽ có_giá là usd usd cho gb và usd cho gb nếu so với ipod nano thì máy không có điểm gì trội hơn tuy_nhiên kiểu_dáng có_thể là một ưu_thế cạnh_tranh của sansa vì dù_sao khách tham_quan vẫn đánh_giá đây là một chiếc máy đầy nữ_tính'

# %%
# import pickle

# pickle.dump(X_data, open('/content/drive/My Drive/NLP/10Topics/Ver1.1/X_data.pkl', 'wb'))
# pickle.dump(y_data, open('/content/drive/My Drive/NLP/10Topics/Ver1.1/y_data.pkl', 'wb'))

# %%
X_data, y_data = get_data('/content/drive/MyDrive/TTTN/Test_Full')
# Out:
# 100%|██████████| 10/10 [23:17<00:00, 139.79s/it]

# %%
len(X_data)
# Out:
# 50373

# %%
import numpy as np
import pandas as pd
df = pd.DataFrame(list(zip(X_data, y_data)),
               columns =['Sentence', 'category_sentence'])

# %%
df.head()
# Out:
#                                             Sentence category_sentence
# 0  sở gd đt đề thi học_kỳ lớp xét tốt_nghiệp thcs...  Chinh tri Xa hoi
# 1  ngày_công_bố danh_sách trường thpt công_lập tự...  Chinh tri Xa hoi
# 2  quỹ tín_dụng sinh_viên nlđ ts lê bảo lâm hiệu_...  Chinh tri Xa hoi
# 3  giảng_dạy đại_học trình_độ giáo_dục đại_học ta...  Chinh tri Xa hoi
# 4  kẹt xe_kéo điểm_nóng cảnh kẹt xe_kéo_dài đường...  Chinh tri Xa hoi

# %%
df.to_csv('data_clean.csv')

# %%
X_data
# Out:
# 0        sở gd đt đề thi học_kỳ lớp xét tốt_nghiệp thcs...
# 1        ngày_công_bố danh_sách trường thpt công_lập tự...
# 2        quỹ tín_dụng sinh_viên nlđ ts lê bảo lâm hiệu_...
# 3        giảng_dạy đại_học trình_độ giáo_dục đại_học ta...
# 4        kẹt xe_kéo điểm_nóng cảnh kẹt xe_kéo_dài đường...
#                                ...
# 50368    nga phản_đối chechnya lhq matxcơva chấp_nhận l...
# 50369    appf thông_qua nghị_quyết đối_phó động_đất són...
# 50370    hwang xin_lỗi dân hàn mong tha_thứ hwang woo s...
# 50371    indonesia tăng_cường an_ninh cảnh_báo mỹ cảnh_...
# 50372    thủ_tướng italy lý_lẽ mỹ vụ bắn điệp_viên thủ_...
# Name: Sentence, Length: 50373, dtype: object

# %%
plt.hist(y_data);

# %%
pickle.dump(X_test, open('/content/drive/My Drive/NLP/10Topics/Ver1.1/X_test.pkl', 'wb'))
pickle.dump(y_test, open('/content/drive/My Drive/NLP/10Topics/Ver1.1/y_test.pkl', 'wb'))

# %%
#word enb
import os
import pickle
X_test = pickle.load(open("/content/drive/My Drive/NLP/10Topics/Ver1.1/X_data.pkl",'rb'))
y_test = pickle.load(open("/content/drive/My Drive/NLP/10Topics/Ver1.1/y_data.pkl",'rb'))
X_data = pickle.load(open("/content/drive/My Drive/NLP/10Topics/Ver1.1/X_test.pkl",'rb'))
y_data = pickle.load(open("/content/drive/My Drive/NLP/10Topics/Ver1.1/y_test.pkl",'rb'))

# %%
with open('/content/drive/MyDrive/TTTN/vietnamese-stopwords-dash.txt', 'r') as f:
    stopwords = set([w.strip() for w in f.readlines()])

# %%
for i in range(len(X_data)):
    text = X_data[i]
    try:
        split_words =  [x.strip('0123456789%@$.,=+-!;/()*"&^:#|\n\t\'').lower() for x in text.split()]
    except TypeError:
        split_words =  []
    X_data[i] = ' '.join([word for word in split_words if word not in stopwords])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
for i in range(len(X_test)):
    text = X_test[i]
    try:
        split_words =  [x.strip('0123456789%@$.,=+-!;/()*"&^:#|\n\t\'').lower() for x in text.split()]
    except TypeError:
        split_words =  []
    X_test[i] = ' '.join([word for word in split_words if word not in stopwords])

# %%
from sklearn.model_selection import train_test_split
x, X_test, y, y_test = train_test_split(X_data, y_data, test_size=0.2)
X_train, X_val, y_train, y_val = train_test_split(x, y, test_size=0.3)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(analyzer='word', max_features=10000)
#Tính tfidf cho tập train
tfidf_vect.fit(X_data)
#pickle.dump(tfidf_vect, open("/content/drive/My Drive/NLP/Model/vectorizer.pickle", "wb"))
x_trainn =  tfidf_vect.transform(X_train)
x_testt =  tfidf_vect.transform(X_test)
x_vall =  tfidf_vect.transform(X_val)
tfidf_X_data = tfidf_vect.transform(X_data)

# %%
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=500, random_state=1998)
svd.fit(tfidf_X_data)
#svd.fit(X_data)
#pickle.dump(svd, open("/content/drive/My Drive/NLP/Model/selector.pickle", "wb"))

x_train = svd.transform(x_trainn)
x_test = svd.transform(x_testt)
x_val = svd.transform(x_vall)

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
model = keras.models.load_model('/content/drive/MyDrive/TTTN/model.h5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-d7a3a176f04c> in <module>()
# ----> 1 model = keras.models.load_model('/content/drive/MyDrive/TTTN/model.h5')
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
# ---> 67       raise e.with_traceback(filtered_tb) from None
#      68     finally:
#      69       del filtered_tb
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     180     model_config = f.attrs.get('model_config')
#     181     if model_config is None:
# --> 182       raise ValueError(f'No model config found in the file at {filepath}.')
# ...

# %%
from keras import models
from keras.models import *
from keras.layers import *
from keras.callbacks import TensorBoard
from keras.callbacks import ModelCheckpoint
#from keras.optimizers import adam
from keras import optimizers
from sklearn.model_selection import train_test_split

# %%
def lstm_model():
    
    input_layer = Input(shape=(500,))
    layer = Reshape((1, 500))(input_layer)
    layer = LSTM(256, activation='relu',dropout=0.4,recurrent_dropout=0.3)(layer)
#     layer = LSTM(128, activation='relu',dropout=0.4,recurrent_dropout=0.3)(layer)
#     keras.layers.RNN(cell, return_sequences=False, return_state=False, go_backwards=False, stateful=False, unroll=False)
    layer = Dense(512, activation='relu')(layer)
#     layer = Dropout(0.3)(layer)
#     layer = Reshape((16, 32))(layer)
#     layer = LSTM(256, activation='relu',dropout=0.4,recurrent_dropout=0.3)(layer)
    layer = Dense(512, activation='relu')(layer)
    layer = Dense(256, activation='relu')(layer)
#     layer = Dropout(0.3)(layer)
    layer = Dense(256, activation='relu')(layer)
    layer = Dense(128, activation='relu')(layer)
#     layer = Dropout(0.3)(layer)
    layer = Dense(128, activation='relu')(layer)
    output_layer = Dense(10, activation='softmax')(layer)
    model = models.Model(input_layer, output_layer)
#     models.Model.summary()
    
    model.compile(optimizer= 'adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

# %%
model = lstm_model()
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 500)]             0
#
#  reshape (Reshape)           (None, 1, 500)            0
#
#  lstm (LSTM)                 (None, 256)               775168
#
#  dense (Dense)               (None, 512)               131584
#
#  dense_1 (Dense)             (None, 512)               262656
#
#  dense_2 (Dense)             (None, 256)               131328
#
#  dense_3 (Dense)             (None, 256)               65792
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dense_5 (Dense)             (None, 128)               16512
#
#  dense_6 (Dense)             (None, 10)                1290
#
# ...
# Total params: 1,417,226
# Trainable params: 1,417,226
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
# visualize model structure

plot_model(model, to_file='model_plot_v1v2.png', show_shapes=True, show_layer_names=True)

# %%
from sklearn.model_selection import train_test_split
x, x_test, y, y_test = train_test_split(tfidf_X_data_svd, y_data, test_size=0.2)
x_train, x_val, y_train, y_val = train_test_split(x, y, test_size=0.3)

# %%
x_test
# Out:
# array([[ 0.16444234, -0.00277047, -0.0327797 , ..., -0.00769942,
#          0.03675908,  0.03762628],
#        [ 0.16311279, -0.0662587 , -0.03805522, ..., -0.05091494,
#         -0.01825388,  0.01362372],
#        [ 0.1938059 , -0.11455463, -0.13735107, ..., -0.04488893,
#         -0.02341809, -0.01571263],
#        ...,
#        [ 0.09996886, -0.03442853,  0.14924771, ..., -0.01043653,
#          0.01067061,  0.00121637],
#        [ 0.13597511, -0.04361589, -0.00991784, ...,  0.00752786,
#         -0.00092897,  0.02338314],
#        [ 0.06621733, -0.02835912,  0.03612999, ..., -0.00164801,
#          0.00526807,  0.00282647]])

# %%
from sklearn import preprocessing
import numpy
encoder = preprocessing.LabelEncoder()
y_data_one_hot = encoder.fit_transform(y_train)
y_test_one_hot = encoder.fit_transform(y_test)
y_val_one_hot = encoder.fit_transform(y_val)
#numpy.save('/content/drive/My Drive/NLP/Model/classes.npy', encoder.classes_)

# %%
y_test_one_hot
# Out:
# array([9, 6, 8, ..., 2, 2, 4])

# %%
# list(y_data_one_hot)

# %%
# encoder.classes_ = numpy.load('/content/drive/My Drive/NLP/Model/classes.npy')

# %%
from sklearn import metrics

def train(model, x_train, y_train, x_val, y_val, x_test, y_test, n_epochs=10):   
    #split training data and validation data
    
    history = model.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=n_epochs, batch_size=512)
    
    train_predictions = model.predict(x_train)
    val_predictions = model.predict(x_val)
    test_predictions = model.predict(x_test)
    
    val_predictions = val_predictions.argmax(axis=-1)
    test_predictions = test_predictions.argmax(axis=-1)
    train_predictions = train_predictions.argmax(axis=-1)

    print("Train accuract", metrics.accuracy_score(train_predictions, y_train))
    print("Validation accuracy: ", metrics.accuracy_score(val_predictions, y_val))
    print("Test accuracy: ", metrics.accuracy_score(test_predictions, y_test))
    
    #model_json = model.to_json()
    #with open("/content/drive/My Drive/NLP/Model/model.json", "w") as json_file:
     #   json_file.write(model_json)
    # serialize weights to HDF5
    model.save_weights("model.h5")
    print("Saved model to disk")

    return history

# %%
history = train(model=model, x_train=x_train, y_train=y_data_one_hot, x_val=x_val, y_val=y_val_one_hot, x_test=x_test, y_test=y_test_one_hot)
# Out:
# Epoch 1/10
# 56/56 [==============================] - 10s 124ms/step - loss: 1.9300 - accuracy: 0.2973 - val_loss: 1.1042 - val_accuracy: 0.6479
# Epoch 2/10
# 56/56 [==============================] - 6s 114ms/step - loss: 1.1168 - accuracy: 0.6153 - val_loss: 0.6123 - val_accuracy: 0.8204
# Epoch 3/10
# 56/56 [==============================] - 6s 114ms/step - loss: 0.7853 - accuracy: 0.7445 - val_loss: 0.5016 - val_accuracy: 0.8439
# Epoch 4/10
# 56/56 [==============================] - 6s 115ms/step - loss: 0.5912 - accuracy: 0.8142 - val_loss: 0.4156 - val_accuracy: 0.8765
# Epoch 5/10
# 56/56 [==============================] - 6s 114ms/step - loss: 0.4880 - accuracy: 0.8458 - val_loss: 0.3751 - val_accuracy: 0.8872
# Epoch 6/10
# 56/56 [==============================] - 6s 116ms/step - loss: 0.4412 - accuracy: 0.8630 - val_loss: 0.3589 - val_accuracy: 0.8915
# Epoch 7/10
# ...

# %%
import matplotlib.pyplot as plt


def visualize(history):
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_acc'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'val_acc'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'val'], loc='upper left')
    plt.show()

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val_acc'], loc='upper left')
plt.show()
    # summarize history for loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
model_json = model.to_json()
with open("/content/drive/My Drive/NLP/Model/model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("/content/drive/My Drive/NLP/Model/model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# encoder = LabelEncoder()
# encoder.classes_ = numpy.load('classes.npy')
l = model.predict(np.array([x_test[1]]))

# %%
l
# Out:
# array([[5.0163275e-04, 3.1909582e-05, 2.8354957e-06, 1.1718131e-05,
#         9.9853683e-01, 1.9737032e-05, 3.3078253e-05, 7.9124508e-04,
#         9.6945280e-07, 7.0121154e-05]], dtype=float32)

# %%
numpy.argmax(l)
# Out:
# 4

# %%
y_test_one_hot[1]
# Out:
# 4

# %%
y_test[1]
# Out:
# 'The gioi'

# %%
# Out:
# 'Chinh tri Xa hoi'

# %%
np.array([tfidf_X_test_svd[1]]).shape
# Out:
# (1, 500)

# %%
tfidf_X_test_svd.shape
# Out:
# (33759, 500)

# %%
y_test_predict = model.predict(x_test)

# %%
y_test_predict[1]
# Out:
# array([7.7148587e-05, 2.3205577e-05, 9.8909941e-06, 7.8300007e-05,
#        6.1894287e-05, 5.0223548e-06, 9.9709821e-01, 6.8450286e-06,
#        6.9362548e-05, 2.5701500e-03], dtype=float32)

# %%
type(y_test_predict)
# Out:
# numpy.ndarray

# %%
y_test1 = np.argmax(y_test_predict, axis=1)

# %%
from sklearn.metrics import classification_report
y_true = y_test_one_hot
y_pred = y_test1
target_names = ['CTXH', 'Đời Sống', 'Kinh Doanh', 'Khoa Học', 'Pháp Luật', 'Sức Khỏe', 'Thế Giới', 'Thể Thao', 'Văn Hóa', 'Vi Tính']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#         CTXH       0.91      0.82      0.86      1503
#     Đời Sống       0.70      0.60      0.64       374
#   Kinh Doanh       0.75      0.78      0.77       439
#     Khoa Học       0.92      0.87      0.89      1061
#    Pháp Luật       0.92      0.90      0.91       755
#     Sức Khỏe       0.89      0.96      0.92      1112
#     Thế Giới       0.94      0.92      0.93      1333
#     Thể Thao       0.98      0.97      0.98      1320
#      Văn Hóa       0.87      0.97      0.92      1245
#      Vi Tính       0.91      0.97      0.94       933
#
#     accuracy                           0.90     10075
#    macro avg       0.88      0.88      0.88     10075
# weighted avg       0.90      0.90      0.90     10075

# %%
y_test1[300:350]
# Out:
# array([0, 0, 9, 3, 6, 7, 8, 0, 3, 9, 6, 8, 6, 7, 7, 6, 0, 4, 3, 5, 1, 6,
#        7, 0, 5, 6, 4, 7, 5, 0, 7, 5, 8, 9, 4, 3, 9, 9, 4, 5, 7, 2, 5, 5,
#        7, 0, 4, 3, 8, 8])

# %%
y_test_one_hot[300:350]
# Out:
# array([0, 0, 9, 3, 6, 7, 8, 0, 3, 9, 6, 8, 6, 7, 7, 6, 0, 4, 3, 5, 1, 6,
#        7, 0, 5, 6, 4, 7, 5, 4, 7, 5, 8, 9, 4, 3, 9, 9, 4, 5, 7, 2, 5, 5,
#        7, 0, 0, 3, 8, 8])

# %%
i = 2
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# Sentence:  kiến trái chiều thu hằng thi hoa_hậu hoàn_vũ tùy_tiện kiểu đẹp thông_minh chẳng dám đi thi hoa_hậu thông_minh một_chút_xíu chẳng_là đẹp lắm đằng gửi thanhle gửi ban biên tậptiêu đề se chang that su dep va thong minh lai đam di_thi hoa hau tùy_tiện kiểu đẹp thông_minh chẳng dám đi thi hoa_hậu thông_minh một_chút_xíu chẳng_là đẹp lắm đằng hoa_hậu việt_nam chẳng trình_độ sánh_vai hoa_hậu_thế_giới gửi jasmine gửi ban văn hoátiêu đề hoa khoi mien bac lai duoc di_thi hoa hau hoan vu vô_cùng nực_cười hai thế_giới phạm thu hằng hoa_khôi bắc hoa_hậu vn đi thi miss universe lạ cơ_quan_chức_quyền lên_tiếng thất_vọng gửi du dang gửi ban văn hoátiêu đề phạm thu hằng miss universe
# Processing...
# result predict label:  8
# True label:  8 Van hoa

# %%
i = 10
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# Sentence:  tịch_thu tàu nước_ngoài vùng_biển quảng_ninh hôm_qua ubnd tỉnh quảng_ninh quyết_định tịch_thu tàu peace số_hiệu ching alastair peter alexander sinh quốc_tịch điều_khiển tàu xuất_phát hong_kong thâm_nhập trái_phép rừng_cấm quốc_gia mùn huyện đảo vân đồn ching lực_lượng an_ninh điều_tra phát_hiện tạm đảo rồng đi xuồng gắn máy tàu giá triệu đồng vn tự_thuật ching nghề giáo_viên viết báo tự_do mục_đích chuyến đi đường thuyền_nhân việt_nam vượt_biên trái_phép hộ_chiếu chính_phủ ching alastair peter alexander giấy_tờ tùy_thân chiều du_lịch bất_hợp_pháp dẫn_độ trở_lại hong_kong
# Processing...
# result predict label:  4
# True label:  4 Phap luat

# %%
i = 200
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = -1
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = -2
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = -4
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# Sentence:  robot đạp xe khoa_học nhật ra_mắt robot nhỏ_bé đi xe_đạp dừng ngã robot murata boy hãng murata chế_tạo kg cm lái_xe tốc_độ cm giây điều_khiển máy_tính dây robot công_bố triển_lãm kết_hợp công_nghệ tiên_tiến makuhari messe tokyo hôm kỹ_sư khâu chế_tạo robot thăng_bằng đi xe_đạp giải_quyết gắn cảm_biến thân robot phép tốc_độ góc nghiêng điều_khiển thăng_bằng murata boy có_giá triệu yên tương_đương usd hãng murata chế_tạo phiên_bản robot đi xe_đạp phiên_bản dừng xe ngã
# Processing...
# result predict label:  2
# True label:  2 Khoa hoc

# %%
i = 25
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = 26
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = 27
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = 30
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = 32
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
i = 346
print('Text Classification')
print('Sentence: ', X_test[i])
print('Processing...')
print('result predict label: ', y_test1[i] )
print('True label: ', y_test_one_hot[i], y_test[i] )
# Out:
# Text Classification
# ...

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, confusion_matrix, precision_recall_fscore_support, precision_score, classification_report
cm = confusion_matrix(y_test_one_hot, y_test1)

# %%
cm
# Out:
# array([[1216,   43,   15,   56,   66,   48,   32,    2,   26,   18],
#        [   3,  282,   23,    2,    4,   24,   11,    2,   27,    9],
#        [   6,   25,  283,    2,    0,   42,   10,    0,    3,   20],
#        [  30,   10,    4, 1006,   12,    4,   18,    1,    6,   22],
#        [  42,    8,    1,    6,  712,    4,    3,    9,    3,    6],
#        [   9,    5,   16,    0,    0, 1045,    4,    1,    1,    1],
#        [   9,   16,   11,   12,    5,   15, 1235,    0,    8,   18],
#        [   2,    7,    0,    1,    2,    2,    9, 1291,    7,    1],
#        [   7,   48,    6,    1,    0,    4,   11,    2, 1153,    1],
#        [   2,    3,    2,    5,    3,    1,    8,    0,    2,  876]])

# %%
# Creates a confusion matrix
#cm = confusion_matrix(y_test, y_pred) 
import seaborn as sns
# Transform to df for easier plotting
cm_df = pd.DataFrame(cm,
                     index = ['CTXH','Đời sống','Kinh Doanh', 'Khoa Học', 'Pháp Luật', 'Sức Khỏe', 'Thế Giới', 'Thể Thao', 'Văn Hóa', 'Vi Tính'], 
                     columns = ['CTXH','Đời sống','Kinh Doanh', 'Khoa Học', 'Pháp Luật', 'Sức Khỏe', 'Thế Giới', 'Thể Thao', 'Văn Hóa', 'Vi Tính'])

plt.figure(figsize=(15,10))
sns.heatmap(cm_df, annot=True, cmap='Blues', fmt='')
plt.title('Text Classification')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
#plt.savefig('Confusion2.png')
